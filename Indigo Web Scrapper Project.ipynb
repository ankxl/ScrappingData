# %%
# import libraries for the project
import pandas as pd
import numpy as np
import time
import datetime
import requests
from bs4 import BeautifulSoup
import smtplib # for sending email reminders
import csv

# %%
# Link for the website that we want to scrape the data from
url = 'https://www.chapters.indigo.ca/en-ca/books/the-programmers-brain-what-every/9781617298677-item.html?ikwid=programmers+brain&ikwsec=Home&ikwidx=0#algoliaQueryId=725be51b2fd6da8590ad0e8ac7acf70a'

# %%
# Get headers --> http://httpbin.org/get
headers ={
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", 
    "Accept-Encoding": "gzip, deflate", 
    "Upgrade-Insecure-Requests": "1", 
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"}

# %%
header = ['Title','Price','Plum Points']

# %%
page =requests.get(url,headers=headers)

# %%
soup1 = BeautifulSoup(page.content,'html.parser')
soup1
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><script nonce="7d10367b-d992-4d65-9f13-72cc8adfd7d7">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"338c3edf7e","applicationID":"285498915","applicationTime":172.762467,"transactionName":"NFFTN0AFCBJVAkNdDQ0bdBtCFgMSRwtEGyUmYB5MCAgJAlUNUhtYAFVFAl4LAU4eTg1HBwwbCxBZEUpODg1YVwMPUR5ZUQUSAFgOUBtYEFFeTAgXDRQ=","queueTime":0,"ttGuid":"04d798cbb0408683","agentToken":null}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"298216068",accountID:"626409",trustKey:"517170",xpid:"UgQBVVZaGwEIUVVbDwgGUw==",licenseKey:"338c3edf7e",applicationID:"285498915"};;/*! For license information please see nr-loader-spa-1.236.0.min.js.LICENSE.txt */
# ...

# %%
soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script nonce="7d10367b-d992-4d65-9f13-72cc8adfd7d7">
# ...

# %%
title = soup2.find(class_='common-title product-title item-page__main-title').get_text().strip()
# price = soup2.find(class_='item-price__normal').get_text().strip().replace('$','')
if soup2.find(class_='item-price__normal') == None:
    price = (soup2.find(class_='item-price__adjusted')
             .contents[1]
             .contents[0]
             .strip()
             .replace('$','')
         )
else:
    price = (soup2.find(class_='item-price__normal')
             .get_text()
             .strip()
             .replace('$','')
        )

plum_points = (soup2.find(class_='earn-plum-points__content')
                   .contents[1]
                   .contents[1]
                   .contents[0]
                   .strip())
print(title)
print(price)
print(plum_points)
# Out:
# The Programmer's Brain: What Every Programmer Needs To Know About Cognition
# 65.99
# 330

# %%
data = [title,price,plum_points]

# %%
# url2 = 'https://www.chapters.indigo.ca/en-ca/books/head-first-design-patterns-building/9781492078005-item.html?ikwsec=Books&ikwidx=8#algoliaQueryId=c698af661ecf25e093af4981bb7bb9e7'
url2='https://www.chapters.indigo.ca/en-ca/books/product/9780345426277-item.html?ref=item_page:richrel:rr_carousel:json1'

# %%
page2 = requests.get(url2)
soup = BeautifulSoup(page2.content,'html.parser')
soup = BeautifulSoup(soup.prettify(),'html.parser')

# %%
title = soup.find(class_='common-title product-title item-page__main-title').get_text().strip()
if soup.find(class_='item-price__normal') == None:
    price = (soup.find(class_='item-price__adjusted')
             .contents[1]
             .contents[0]
             .strip()
             .replace('$','')
         )
else:
    price = (soup.find(class_='item-price__normal')
             .get_text()
             .strip()
             .replace('$','')
        )
plum_points = (soup.find(class_='earn-plum-points__content')
                   .contents[1]
                   .contents[1]
                   .contents[0]
                   .strip())
print(title)
print(price)
print(plum_points)
# Out:
# The Analyst: A Novel
# 11.99
# 60

# %%
data1=[title,price,plum_points]

# %%
with open('IndigoWebScrapper.csv','w',newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)
    writer.writerow(data1)

# %%
today = datetime.date.today()
print(today)
# Out:
# 2023-08-02

# %%
df = pd.read_csv('amazon_web_scraper_dataset.csv')
df

# %%
def check_price():
    
    # connect to the website
    url = 'https://www.amazon.ca/Business-Analyst-Tshirt-Scientist-T-Shirt/dp/B0B3DJCMDT/ref=sr_1_4?crid=27MZ0UY0OP0YD&keywords=data%2Banalyst%2Btshirt&qid=1680552562&sprefix=data%2Banalyst%2Btshir%2Caps%2C201&sr=8-4&th=1&psc=1'
    
    # Get headers --> http://httpbin.org/get
    headers ={
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", 
        "Accept-Encoding": "gzip, deflate", 
        "Accept-Language": "en-US,en;q=0.9",
        "Upgrade-Insecure-Requests": "1", 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"}
    
    page =requests.get(url, headers=headers)
    
    soup1 = BeautifulSoup(page.content,'html.parser')
    
    soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
    
    title = soup2.find(id='productTitle').get_text().strip()
    price = soup2.find(class_='a-offscreen').get_text().strip().replace('$','')
    
    today = datetime.date.today()
    
    data = [title,float(price),today]

    with open('amazon_web_scraper_dataset.csv','a+',newline='',encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    
    if price < 10:
        send_mail()

# %%
while(True):
    check_price()
    time.sleep(5)

# %%
df = pd.read_csv('amazon_web_scraper_dataset.csv')
df

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    # server.starttls()
    server.ehlo()
    server.login('ankitrai@gmail.com','xxxxxxxxxxx')
    
    subject = 'The shirt you want to buy is less than $15 Now is your chance to buy'
    body ='Got to buy it now'
    
    msg = f'Subject: {subject}\n\n{body}'
    
    server.sendmail('ankitrai@gmail.com',msg)
